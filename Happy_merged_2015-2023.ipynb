# %%
import pandas as pd

df = pd.read_csv('merged_data.csv')
df.shape
# Out:
# (1368, 12)

# %%
df.head()
# Out:
#    Year      Country                           Region  Happiness_Rank  \
# 0  2023      Finland                   Western Europe               1
# 1  2023      Denmark                   Western Europe               2
# 2  2023      Iceland                   Western Europe               3
# 3  2023       Israel  Middle East and Northern Africa               4
# 4  2023  Netherlands                   Western Europe               5
#
#    Happiness  Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# 0      7.804               0.535             1.888                 0.772
# 1      7.586               0.525             1.949                 0.734
# 2      7.530               0.187             1.926                 0.738
# 3      7.473               0.158             1.833                 0.569
# 4      7.403               0.394             1.942                 0.672
#
#    Explained_by_Generosity  Explained_by_Health  Explained_by_Social_support  \
# ...

# %%
df.isnull().sum()
# Out:
# Year                            0
# Country                         0
# Region                         67
# Happiness_Rank                  0
# Happiness                       1
# Explained_by_Trust              2
# Explained_by_GDP                1
# Explained_by_Freedom            1
# Explained_by_Generosity         1
# Explained_by_Health             2
# Explained_by_Social_support     1
# Dystopia_Residual               3
# dtype: int64

# %%
null_region = df['Region'].isnull() == True
df.loc[null_region,:]
# Out:
#       Year                    Country Region  Happiness_Rank  Happiness  \
# 17    2023                    Czechia    NaN              18      6.845
# 26    2023   Taiwan Province of China    NaN              27      6.535
# 81    2023  Hong Kong S.A.R. of China    NaN              82      5.308
# 86    2023            North Macedonia    NaN              87      5.254
# 98    2023         State of Palestine    NaN              99      4.908
# ...    ...                        ...    ...             ...        ...
# 947   2017                     Belize    NaN              50      5.956
# 968   2017    Hong Kong S.A.R., China    NaN              71      5.472
# 990   2017                    Somalia    NaN              93      5.151
# 1008  2017                    Namibia    NaN             111      4.574
# 1044  2017                South Sudan    NaN             147      3.591
#
#       Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# ...

# %%
df['Region'].unique()
# Out:
# array(['Western Europe', 'Middle East and Northern Africa',
#        'Australia and New Zealand', 'North America', nan,
#        'Central and Eastern Europe', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Eastern Asia', 'Sub-Saharan Africa',
#        'Southern Asia'], dtype=object)
