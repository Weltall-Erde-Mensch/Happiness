# %%
import pandas as pd
import panel as pn
import numpy as np
import hvplot.pandas
import folium
from panel.interact import interact
pn.extension('tabulator')
pn.extension
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# panel.config.panel_extension

# %%
df = pd.read_csv('Data/merged_data.csv', sep=',')
df.head()
# Out:
#    Year      Country                           Region  Happiness_Rank  \
# 0  2023      Finland                   Western Europe               1
# 1  2023      Denmark                   Western Europe               2
# 2  2023      Iceland                   Western Europe               3
# 3  2023       Israel  Middle East and Northern Africa               4
# 4  2023  Netherlands                   Western Europe               5
#
#    Happiness  Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# 0      7.804               0.535             1.888                 0.772
# 1      7.586               0.525             1.949                 0.734
# 2      7.530               0.187             1.926                 0.738
# 3      7.473               0.158             1.833                 0.569
# 4      7.403               0.394             1.942                 0.672
#
#    Explained_by_Generosity  Explained_by_Health  Explained_by_Social_support  \
# 0                    0.126                0.535                        1.585
# 1                    0.208                0.537                        1.548
# 2                    0.250                0.559                        1.620
# 3                    0.124                0.577                        1.521
# 4                    0.251                0.545                        1.488
#
#    Dystopia_Residual
# 0              2.363
# 1              2.084
# 2              2.250
# 3              2.691
# 4              2.110

# %%
# cache data to improve dashboard performance
if 'data' not in pn.state.cache.keys():

    df = pd.read_csv('Data/merged_data.csv', sep=',')

    pn.state.cache['data'] = df.copy()

else: 

    df = pn.state.cache['data']

# %%
df.shape
# Out:
# (1368, 12)

# %%
df.isnull().sum()
# Out:
# Year                            0
# Country                         0
# Region                         67
# Happiness_Rank                  0
# Happiness                       1
# Explained_by_Trust              2
# Explained_by_GDP                1
# Explained_by_Freedom            1
# Explained_by_Generosity         1
# Explained_by_Health             2
# Explained_by_Social_support     1
# Dystopia_Residual               3
# dtype: int64

# %%
cero_happiness = df['Happiness'].isnull() == True
df.loc[cero_happiness,:]
# Out:
#      Year Country Region  Happiness_Rank  Happiness  Explained_by_Trust  \
# 283  2022      xx    NaN             147        NaN                 NaN
#
#      Explained_by_GDP  Explained_by_Freedom  Explained_by_Generosity  \
# 283               NaN                   NaN                      NaN
#
#      Explained_by_Health  Explained_by_Social_support  Dystopia_Residual
# 283                  NaN                          NaN                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         1368 non-null   int64
#  1   Country                      1368 non-null   object
#  2   Region                       1301 non-null   object
#  3   Happiness_Rank               1368 non-null   int64
#  4   Happiness                    1367 non-null   float64
#  5   Explained_by_Trust           1366 non-null   float64
#  6   Explained_by_GDP             1367 non-null   float64
#  7   Explained_by_Freedom         1367 non-null   float64
#  8   Explained_by_Generosity      1367 non-null   float64
#  9   Explained_by_Health          1366 non-null   float64
#  10  Explained_by_Social_support  1367 non-null   float64
#  11  Dystopia_Residual            1365 non-null   float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 128.4+ KB

# %%
df.nunique()
# Out:
# Year                              9
# Country                         198
# Region                           10
# Happiness_Rank                  158
# Happiness                      1200
# Explained_by_Trust              901
# Explained_by_GDP               1222
# Explained_by_Freedom           1027
# Explained_by_Generosity         914
# Explained_by_Health            1093
# Explained_by_Social_support    1166
# Dystopia_Residual              1290
# dtype: int64

# %%
df.Region.value_counts()
# Out:
# Region
# Sub-Saharan Africa                 309
# Central and Eastern Europe         249
# Latin America and Caribbean        185
# Western Europe                     184
# Middle East and Northern Africa    155
# Southeastern Asia                   80
# Southern Asia                       59
# Eastern Asia                        44
# Australia and New Zealand           18
# North America                       18
# Name: count, dtype: int64

# %%
glob_rank = df.groupby('Country')[['Happiness_Rank','Year']].min()
glob_rank
# Out:
#              Happiness_Rank  Year
# Country
# Afghanistan             137  2015
# Albania                  83  2015
# Algeria                  38  2015
# Angola                  137  2015
# Argentina                24  2015
# ...                     ...   ...
# Yemen                   136  2015
# Yemen*                  132  2022
# Zambia                   85  2015
# Zimbabwe                115  2015
# xx                      147  2022
#
# [198 rows x 2 columns]

# %%
glob_hap_max = df.groupby('Year')['Happiness'].max()
glob_hap_mean = df.groupby('Year')['Happiness'].mean()
glob_hap_min = df.groupby('Year')['Happiness'].min()

# %%
country_happiness = df.groupby('Country')[['Year','Happiness','Happiness_Rank']]

# %%
rank_1 = df['Happiness_Rank'] == 1
df.loc[rank_1,:]
# Out:
#       Year      Country          Region  Happiness_Rank  Happiness  \
# 0     2023      Finland  Western Europe               1     7.8040
# 137   2022      Finland  Western Europe               1     7.8210
# 284   2021      Finland  Western Europe               1     7.8420
# 433   2020      Finland  Western Europe               1     7.8087
# 586   2019      Finland  Western Europe               1     7.7690
# 742   2018      Finland  Western Europe               1     7.6320
# 898   2017       Norway  Western Europe               1     7.5370
# 1053  2016      Denmark  Western Europe               1     7.5260
# 1210  2015  Switzerland  Western Europe               1     7.5870
#
#       Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# 0               0.535000          1.888000              0.772000
# 137             0.534000          1.892000              0.736000
# 284             0.481000          1.446000              0.691000
# 433             0.477857          1.285190              0.662317
# 586             0.393000          1.340000              0.596000
# 742             0.393000          1.305000              0.681000
# 898             0.315964          1.616463              0.635423
# 1053            0.444530          1.441780              0.579410
# 1210            0.419780          1.396510              0.665570
#
#       Explained_by_Generosity  Explained_by_Health  \
# 0                    0.126000             0.535000
# 137                  0.109000             0.775000
# 284                  0.124000             0.741000
# 433                  0.159670             0.961271
# 586                  0.153000             0.986000
# 742                  0.202000             0.874000
# 898                  0.362012             0.796667
# 1053                 0.361710             0.795040
# 1210                 0.296780             0.941430
#
#       Explained_by_Social_support  Dystopia_Residual
# 0                        1.585000           2.363000
# 137                      1.258000           2.518000
# 284                      1.106000           3.253000
# 433                      1.499526           2.762835
# 586                      1.587000           2.714000
# 742                      1.592000           2.585000
# 898                      1.533524           2.277027
# 1053                     1.163740           2.739390
# 1210                     1.349510           2.517380

# %%
rank_2 = df['Happiness_Rank'] == 2
df.loc[rank_2,:]
# Out:
#       Year      Country          Region  Happiness_Rank  Happiness  \
# 1     2023      Denmark  Western Europe               2     7.5860
# 138   2022      Denmark  Western Europe               2     7.6360
# 285   2021      Denmark  Western Europe               2     7.6200
# 434   2020      Denmark  Western Europe               2     7.6456
# 587   2019      Denmark  Western Europe               2     7.6000
# 743   2018       Norway  Western Europe               2     7.5940
# 899   2017      Denmark  Western Europe               2     7.5220
# 1054  2016  Switzerland  Western Europe               2     7.5090
# 1211  2015      Iceland  Western Europe               2     7.5610
#
#       Explained_by_Trust  Explained_by_GDP  Explained_by_Freedom  \
# 1                0.52500          1.949000              0.734000
# 138              0.53200          1.953000              0.719000
# 285              0.48500          1.502000              0.686000
# 434              0.49526          1.326949              0.665040
# 587              0.41000          1.383000              0.592000
# 743              0.34000          1.456000              0.686000
# 899              0.40077          1.482383              0.626007
# 1054             0.41203          1.527330              0.585570
# 1211             0.14145          1.302320              0.628770
#
#       Explained_by_Generosity  Explained_by_Health  \
# 1                    0.208000             0.537000
# 138                  0.188000             0.777000
# 285                  0.208000             0.763000
# 434                  0.242793             0.979333
# 587                  0.252000             0.996000
# 743                  0.286000             0.861000
# 899                  0.355280             0.792566
# 1054                 0.280830             0.863030
# 1211                 0.436300             0.947840
#
#       Explained_by_Social_support  Dystopia_Residual
# 1                        1.548000           2.084000
# 138                      1.243000           2.226000
# 285                      1.108000           2.868000
# 434                      1.503449           2.432741
# 587                      1.573000           2.394000
# 743                      1.582000           2.383000
# 899                      1.551122           2.313707
# 1054                     1.145240           2.694630
# 1211                     1.402230           2.702010

# %%
df['Happiness_Rank'].max()
# Out:
# 158

# %%
df['Happiness'].min()
# Out:
# 1.859

# %% [markdown]
# # Make df interactive

# %%
idf = df.interactive()

# %%
idf.head(1)
# Out:
# <div id='cbf84622-57d6-4904-b696-27e9af2e3a26'>
#   <div id="dabc6ac0-e92d-4454-b0f7-1533c18db119" data-root-id="cbf84622-57d6-4904-b696-27e9af2e3a26" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"faf1816a-6778-4ebc-b161-ca04a8266f8f":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"cbf84622-57d6-4904-b696-27e9af2e3a26","attributes":{"name":"Row00900","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"71d15ad4-1609-4cfb-b727-8396572c5365","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4a6a5001-afae-46c6-9737-7e68855734de","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"51293da1-f96c-4cc0-b72b-5908eb0856df","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"cf554471-e631-4593-887d-a88ee2327bf1","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"48f114d5-110a-4ecc-b48b-589e15a30141","attributes":{"name":"Column00885","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"71d15ad4-1609-4cfb-b727-8396572c5365"},{"id":"4a6a5001-afae-46c6-9737-7e68855734de"},{"id":"51293da1-f96c-4cc0-b72b-5908eb0856df"},{"id":"cf554471-e631-4593-887d-a88ee2327bf1"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"286c361c-4d52-463d-8c59-4bd8dc0e2bb4","attributes":{"name":"Column00897","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"71d15ad4-1609-4cfb-b727-8396572c5365"},{"id":"4a6a5001-afae-46c6-9737-7e68855734de"},{"id":"51293da1-f96c-4cc0-b72b-5908eb0856df"},{"id":"cf554471-e631-4593-887d-a88ee2327bf1"}],"margin":0,"align":"start"}},{"type":"object","name":"Row","id":"c464ebfc-5ddc-4ea7-9f53-444b46768d23","attributes":{"name":"Row00894","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"71d15ad4-1609-4cfb-b727-8396572c5365"},{"id":"4a6a5001-afae-46c6-9737-7e68855734de"},{"id":"51293da1-f96c-4cc0-b72b-5908eb0856df"},{"id":"cf554471-e631-4593-887d-a88ee2327bf1"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"ce955f96-b143-468f-9334-7a0399857d3b","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"71d15ad4-1609-4cfb-b727-8396572c5365"},{"type":"object","name":"ImportedStyleSheet","id":"5f6ad6fd-ef43-4bdf-a1ba-27058a753569","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/dataframe.css"}},{"id":"51293da1-f96c-4cc0-b72b-5908eb0856df"},{"id":"cf554471-e631-4593-887d-a88ee2327bf1"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Year&lt;/th&gt;\n      &lt;th&gt;Country&lt;/th&gt;\n      &lt;th&gt;Region&lt;/th&gt;\n      &lt;th&gt;Happiness_Rank&lt;/th&gt;\n      &lt;th&gt;Happiness&lt;/th&gt;\n      &lt;th&gt;Explained_by_Trust&lt;/th&gt;\n      &lt;th&gt;Explained_by_GDP&lt;/th&gt;\n      &lt;th&gt;Explained_by_Freedom&lt;/th&gt;\n      &lt;th&gt;Explained_by_Generosity&lt;/th&gt;\n      &lt;th&gt;Explained_by_Health&lt;/th&gt;\n      ...

# %% [markdown]
# # Define Panel Widgets

# %%
from bokeh.models.formatters import PrintfTickFormatter

rank_slider = pn.widgets.IntSlider(name='Happiness Rank', start=1, end=158, step=1, value=1)
rank_slider
# Out:
# IntSlider(end=158, name='Happiness Rank', start=1, value=1)

# %%
# Radio buttons for CO2 measures
yaxis_Happiness = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Happiness'],
    button_type='success'
)

# %%
year = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022','2023']

happiness_pipeline = (
    idf[
        (idf.Happiness_Rank <= rank_slider) #&
        #(idf.Year.isin(year))
    ]
    .groupby(['Country', 'Year']).min()
    #.to_frame()
    .reset_index()
    .sort_values(by='Happiness_Rank', ascending=True)  
    #.reset_index(drop=True)
)

# %%
happiness_pipeline[-10:]
# Out:
# <div id='8f3ec01e-361e-461e-bd85-d9acdb0b04e0'>
#   <div id="f6a6aa71-f3af-4e4a-896c-fa6a75a6a3b5" data-root-id="8f3ec01e-361e-461e-bd85-d9acdb0b04e0" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"2e4d5c14-7d99-4845-952c-6e28b8b529b5":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"8f3ec01e-361e-461e-bd85-d9acdb0b04e0","attributes":{"name":"Row01299","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"3ea76155-ad35-4052-91b7-7a54d7a38e93","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8aa1e891-6902-4a9f-91ff-e955fe46dd50","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"b452797d-6e85-41e0-a770-38c90dfe529e","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f193d67c-695d-4967-9af2-9b054e700a7d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"5a32aadc-f343-4207-bdc4-bc12a9f1a253","attributes":{"name":"Column01296","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"3ea76155-ad35-4052-91b7-7a54d7a38e93"},{"id":"8aa1e891-6902-4a9f-91ff-e955fe46dd50"},{"id":"b452797d-6e85-41e0-a770-38c90dfe529e"},{"id":"f193d67c-695d-4967-9af2-9b054e700a7d"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"05f70857-78ba-4e46-8066-db1e9494492c","attributes":{"name":"Column01266","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"3ea76155-ad35-4052-91b7-7a54d7a38e93"},{"id":"8aa1e891-6902-4a9f-91ff-e955fe46dd50"},{"id":"b452797d-6e85-41e0-a770-38c90dfe529e"},{"id":"f193d67c-695d-4967-9af2-9b054e700a7d"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"cd451109-2bdf-4936-a80b-500931f01c0e","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"3ea76155-ad35-4052-91b7-7a54d7a38e93"},{"id":"b452797d-6e85-41e0-a770-38c90dfe529e"},{"id":"f193d67c-695d-4967-9af2-9b054e700a7d"}],"margin":[5,10],"align":"start","title":"Happiness Rank","start":1,"end":158,"value":1}}]}},{"type":"object","name":"panel.models.layout.Column","id":"a317571a-e3f1-497e-b0c4-5a0ef193e23d","attributes":{"name":"Column01281","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"
stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"6e4d686d-f79e-4372-90e0-fc0d02eac256","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"20179164-9287-4d6c-977a-1435c7512699","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"112e5be3-306a-4256-8f51-ab4e61e7c091","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5060f078-d2ae-4f4d-9217-b76adde930ce","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"7b34aaa6-5241-49f8-aaf6-583e2e9da017","attributes":{"name":"Column101381","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"6e4d686d-f79e-4372-90e0-fc0d02eac256"},{"id":"20179164-9287-4d6c-977a-1435c7512699"},{"id":"112e5be3-306a-4256-8f51-ab4e61e7c091"},{"id":"5060f078-d2ae-4f4d-9217-b76adde930ce"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"7c97a670-f284-43b2-b72b-f48a623946fe","attributes":{"name":"Column101393","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"6e4d686d-f79e-4372-90e0-fc0d02eac256"},{"id":"20179164-9287-4d6c-977a-1435c7512699"},{"id":"112e5be3-306a-4256-8f51-ab4e61e7c091"},{"id":"5060f078-d2ae-4f4d-9217-b76adde930ce"}],"margin":0,"align":"start"}},{"type":"object","name":"Row","id":"3f3b01ed-0b74-41cc-8fa7-d4ebf01b4783","attributes":{"name":"Row101390","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"6e4d686d-f79e-4372-90e0-fc0d02eac256"},{"id":"20179164-9287-4d6c-977a-1435c7512699"},{"id":"112e5be3-306a-4256-8f51-ab4e61e7c091"},{"id":"5060f078-d2ae-4f4d-9217-b76adde930ce"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"aa9e7e01-c1f3-4bd7-a1c9-e252dcae39a6","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"6e4d686d-f79e-4372-90e0-fc0d02eac256"},{"type":"object","name":"ImportedStyleSheet","id":"ecb1e305-9532-49cb-bfd8-4ff5b4ef0a13","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/dataframe.css"}},{"id":"112e5be3-306a-4256-8f51-ab4e61e7c091"},{"id":"5060f078-d2ae-4f4d-9217-b76adde930ce"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe panel-df&quot;&gt;\n  &lt;thead&gt;\n    &lt;tr style=&quot;text-align: right;&quot;&gt;\n      &lt;th&gt;&lt;/th&gt;\n      &lt;th&gt;Year&lt;/th&gt;\n      &lt;th&gt;Country&lt;/th&gt;\n      &lt;th&gt;Region&lt;/th&gt;\n      &lt;th&gt;Happiness_Rank&lt;/th&gt;\n      &lt;th&gt;Happiness&lt;/th&gt;\n      &lt;th&gt;Explained_by_Trust&lt;/th&gt;\n      &lt;th&gt;Explained_by_GDP&lt;/th&gt;\n      &lt;th&gt;Explained_by_Freedom&lt;/th&gt;\n      &lt;th&gt;Explained_by_Generosity&lt;/th&gt;\n      &lt;th&gt;Explained_by_Health&lt;/th&gt;\n  ...

# %%
year = ['2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022','2023']

happiness_pipeline_test = (
    idf[
        (idf.Happiness_Rank <= rank_slider) #&
        #(idf.Year.isin(year))
    ]
    .sort_values(by='Year', ascending=True)
    #.groupby(['Country', 'Year']).min()
    #.to_frame()
    #.reset_index()
    #.sort_values(by='Happiness_Rank', ascending=True)  
    #.reset_index(drop=True)
)

#rank = idf['Happiness_Rank'] == rank_slider.value
#no_1_2015_2023 = 
#idf.loc[rank,:].sort_values(by='Year', ascending=True)
happiness_pipeline_test
# Out:
# <div id='9c8c7a0a-95c3-4cd7-b6d2-56a19b6ce892'>
#   <div id="b6da62ae-9476-4997-879b-d5f50c314dae" data-root-id="9c8c7a0a-95c3-4cd7-b6d2-56a19b6ce892" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3d67d2f0-ed28-41ab-80d4-45d04bd604d3":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"9c8c7a0a-95c3-4cd7-b6d2-56a19b6ce892","attributes":{"name":"Row175325","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"e928a6ea-ca83-4efd-be98-e42b2b735034","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"c2f59311-4496-49ae-8efa-fadfd63e86a1","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"eaf23673-2f73-444c-8e37-529f8de9b2de","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"71b1576e-0a36-49d1-ada9-2f0e7f3a29bf","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"8137edf8-a2a2-46ff-8178-de0193059ef5","attributes":{"name":"Column175322","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e928a6ea-ca83-4efd-be98-e42b2b735034"},{"id":"c2f59311-4496-49ae-8efa-fadfd63e86a1"},{"id":"eaf23673-2f73-444c-8e37-529f8de9b2de"},{"id":"71b1576e-0a36-49d1-ada9-2f0e7f3a29bf"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"5886167f-64da-4ce1-a1f4-2ed5edfb8d57","attributes":{"name":"Column175292","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e928a6ea-ca83-4efd-be98-e42b2b735034"},{"id":"c2f59311-4496-49ae-8efa-fadfd63e86a1"},{"id":"eaf23673-2f73-444c-8e37-529f8de9b2de"},{"id":"71b1576e-0a36-49d1-ada9-2f0e7f3a29bf"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"664fc23a-f14f-4b7b-8aca-0eafb0949ce0","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e928a6ea-ca83-4efd-be98-e42b2b735034"},{"id":"eaf23673-2f73-444c-8e37-529f8de9b2de"},{"id":"71b1576e-0a36-49d1-ada9-2f0e7f3a29bf"}],"margin":[5,10],"align":"start","title":"Happiness Rank","start":1,"end":158,"value":24}}]}},{"type":"object","name":"panel.models.layout.Column","id":"707bc936-510b-4b7c-b595-cc3f79d1814e","attributes":{"name":"Column175307","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e928a6ea-ca83-4efd-be98-e42b2b735034"},{"id":"c2f59311-4496-49ae-8efa-fadfd63e86a1"},{"id":"eaf23673-2f73-444c-8e37-529f8de9b2de"},{"id":"71b1576e-0a36-49d1-ada9-2f0e7f3a29bf"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"2d656eec-8fa2-4fb3-89f4-ac7f2d2bee16","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"e928a6ea-ca83-4efd-be98-e42b2b735034"},{"type":"object","name":"ImportedStyleSheet","id":"621ce4c8-957a-4450-85be-b56bcfee7587","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/dataframe.css"}},{"id":"eaf23673-2f73-444c-8e37-529f8de9b2de"},{"id":"71b1576e-0a36-49d1-ada9-2f0e7f3a29bf"}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;data ...

# %%
yaxis_Happiness_test = pn.widgets.RadioButtonGroup(
    name='Y axis', 
    options=['Happiness'],
    button_type='success'
)

# %%
happiness_plot_test = happiness_pipeline_test.hvplot.line(x='Year', 
                                                     by='Country', 
                                                     y=yaxis_Happiness_test, 
                                                     line_width=1.5, title="test", 
                                                     grid=True, 
                                                     hover_cols='Happiness_Rank',
                                                     cmap='Dark2',
                                                         width=800,
                                                         height=400)
happiness_plot_test
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# C:\Users\User\anaconda3\Lib\site-packages\holoviews\core\data\pandas.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return dataset.data.dtypes[idx].type
# <div id='dcebb56c-7ad5-4fbc-83b9-4161aff0d6be'>
#   <div id="c19ef496-c758-47f2-b214-0773f3cfe970" data-root-id="dcebb56c-7ad5-4fbc-83b9-4161aff0d6be" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"2360ee0f-e471-45e4-91af-0cf261b9bd76":{"version":"3.2.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"dcebb56c-7ad5-4fbc-83b9-4161aff0d6be","attributes":{"name":"Row214112","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"058d839d-c462-45d3-bf4d-4e1f996b144d","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"83ca2eb1-712c-406f-8d1f-00cafd815f92","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4834dfb7-1bce-40ad-ad14-aa9f62fdf59c","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"6ebf5dd2-b170-4c86-b287-07eed5c2214f","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"bb1e15a0-c3e1-4e63-835c-db92489398ff","attributes":{"name":"Column214109","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"058d839d-c462-45d3-bf4d-4e1f996b144d"},{"id":"83ca2eb1-712c-406f-8d1f-00cafd815f92"},{"id":"4834dfb7-1bce-40ad-ad14-aa9f62fdf59c"},{"id":"6ebf5dd2-b170-4c86-b287-07eed5c2214f"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"7da5d474-1c34-49cc-b311-81b98de5361e","attributes":{"name":"Column214092","stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"058d839d-c462-45d3-bf4d-4e1f996b144d"},{"id":"83ca2eb1-712c-406f-8d1f-00cafd815f92"},{"id":"4834dfb7-1bce-40ad-ad14-aa9f62fdf59c"},{"id":"6ebf5dd2-b170-4c86-b287-07eed5c2214f"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"f43d2a08-a91a-4e2d-8b12-c15f3671bd44","attributes":{"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"058d839d-c462-45d3-bf4d-4e1f996b144d"},{"id":"4834dfb7-1bce-40ad-ad14-aa9f62fdf59c"},{"id":"6ebf5dd2-b170-4c86-b287-07eed5c2214f"}],"margin":[5,10],"align":"start","title":"Happiness Rank","start":1,"end":158,"value":8}},{"type":"object","name":"RadioButtonGroup","id":"4b9a994f-e1a2-4ac1-999a-35ab7641d354","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading.pn-arc):before, .pn-loading.pn-arc:before {\n  background-image: url(\"data:image/svg+xml;base64,...\");\n  background-size: auto calc(min(50%, 400px));\n}",{"id":"058d839d-c462-45d3-bf4d-4e1f996b144d"},{"type":"object","name":"ImportedStyleSheet","id":"d39445ac-b975-469c-9b59-c0209f9a76fb","attributes":{"url":"https://cdn.holoviz.org/panel/1.2.3/dist/css/button.css"}},{"id":"4834dfb7-1bce-40ad-ad14-aa9f62fdf59c"},{"id":"6ebf5dd2-b170-4c86-b287-07eed5c2214f"}],"margin":[5,10],"align":"start","labels":["Happiness"],"active":0}}]}},{"type":"object","name":"Figure","id":"501f8e25-850f-45ec-8d13-70585844c606","attributes":{"width":800,"height":400,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"ebd76689-ffcd-4ab4-88d9-c08c7daa937a","attributes":{"tags":[[["Year","Year",null]],[]],"start":2015.0,"end":2023.0,"reset_start":2015.0,"reset_end":2023.0}},"y_range":{"type":"object","name":"Range1d","id":"c6e19fa6-db00-46ba-9091-7b501e174741","attributes":{"tags":[[["Happiness","Happiness" ...
